# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0

# %%
pip install gwr
# Out:
# Collecting gwr
#   Downloading gwr-1.0.1.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from gwr) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from gwr) (1.11.4)
# Requirement already satisfied: libpysal in /opt/conda/lib/python3.10/site-packages (from gwr) (4.9.2)
# Requirement already satisfied: pysal in /opt/conda/lib/python3.10/site-packages (from gwr) (24.1)
# Requirement already satisfied: spglm in /opt/conda/lib/python3.10/site-packages (from gwr) (1.1.0)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr) (4.12.2)
# Requirement already satisfied: geopandas>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr) (0.14.3)
# Collecting packaging>=22 (from libpysal->gwr)
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr) (4.2.0)
# Requirement already satisfied: requests>=2.27 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr) (2.31.0)
# Collecting shapely>=2.0.1 (from libpysal->gwr)
#   Downloading shapely-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: access>=1.1.8 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (1.1.9)
# Requirement already satisfied: esda>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (2.5.1)
# Requirement already satisfied: giddy>=2.3.3 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (2.3.5)
# Requirement already satisfied: inequality>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (1.0.1)
# Requirement already satisfied: pointpats>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (2.4.0)
# Requirement already satisfied: segregation>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (2.5)
# Requirement already satisfied: spaghetti>=1.6.6 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (1.7.5.post1)
# Requirement already satisfied: mgwr>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (2.2.1)
# Requirement already satisfied: momepy>=0.5.3 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (0.7.0)
# Requirement already satisfied: spint>=1.0.7 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (1.0.7)
# Requirement already satisfied: spreg>=1.2.4 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (1.4.2)
# Requirement already satisfied: spvcm>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (0.3.0)
# Requirement already satisfied: tobler>=0.8.2 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (0.11.2)
# Requirement already satisfied: mapclassify>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (2.6.1)
# Requirement already satisfied: splot>=1.1.5.post1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr) (0.6.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.10->libpysal->gwr) (2.5)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.10/site-packages (from esda>=2.4.1->pysal->gwr) (1.2.2)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal->gwr) (1.9.6)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal->gwr) (3.6.1)
# Requirement already satisfied: quantecon>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from giddy>=2.3.3->pysal->gwr) (0.7.2)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.10/site-packages (from mapclassify>=2.4.3->pysal->gwr) (3.2.1)
# Requirement already satisfied: tqdm>=4.63.0 in /opt/conda/lib/python3.10/site-packages (from momepy>=0.5.3->pysal->gwr) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal->gwr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal->gwr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal->gwr) (2023.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from pointpats>=2.2.0->pysal->gwr) (3.7.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr) (2024.2.2)
# Requirement already satisfied: deprecation in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->gwr) (2.1.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->gwr) (1.4.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->gwr) (0.12.2)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal->gwr) (0.58.1)
# Requirement already satisfied: rtree>=1.0 in /opt/conda/lib/python3.10/site-packages (from spaghetti>=1.6.6->pysal->gwr) (1.2.0)
# Requirement already satisfied: pulp>=2.7 in /opt/conda/lib/python3.10/site-packages (from spopt>=0.4.1->pysal->gwr) (2.8.0)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.10/site-packages (from tobler>=0.8.2->pysal->gwr) (1.3.10)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from tobler>=0.8.2->pysal->gwr) (0.14.1)
# Requirement already satisfied: rasterstats in /opt/conda/lib/python3.10/site-packages (from tobler>=0.8.2->pysal->gwr) (0.19.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr) (23.2.0)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr) (1.16.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal->gwr) (1.12)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->segregation>=2.3.1->pysal->gwr) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0->esda>=2.4.1->pysal->gwr) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal->gwr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal->gwr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal->gwr) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal->gwr) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal->gwr) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal->gwr) (3.1.1)
# Requirement already satisfied: affine in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->gwr) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->gwr) (1.4.7)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal->gwr) (69.0.3)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.10/site-packages (from rasterstats->tobler>=0.8.2->pysal->gwr) (3.19.2)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels->tobler>=0.8.2->pysal->gwr) (0.5.6)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal->gwr) (1.3.0)
# Downloading packaging-24.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 2.5 MB/s eta 0:00:00
# Downloading shapely-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 35.5 MB/s eta 0:00:0000:01
# Building wheels for collected packages: gwr
#   Building wheel for gwr (setup.py) ... done
#   Created wheel for gwr: filename=gwr-1.0.1-py3-none-any.whl size=16934 sha256=492079ad7ec1d7273273b721bb8a0781cb58d93b26c5cf14a14aab9505bc92ad
#   Stored in directory: /root/.cache/pip/wheels/c2/2c/e3/ac0405348e961bd6c29fb47b60460316f30870d961f83081c4
# Successfully built gwr
# Installing collected packages: shapely, packaging, gwr
#   Attempting uninstall: shapely
#     Found existing installation: Shapely 1.8.5.post1
#     Uninstalling Shapely-1.8.5.post1:
#       Successfully uninstalled Shapely-1.8.5.post1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.9.3 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.0 which is incompatible.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gwr-1.0.1 packaging-24.0 shapely-2.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pysal
# Out:
# Requirement already satisfied: pysal in /opt/conda/lib/python3.10/site-packages (24.1)
# Requirement already satisfied: libpysal>=4.6.2 in /opt/conda/lib/python3.10/site-packages (from pysal) (4.9.2)
# Requirement already satisfied: access>=1.1.8 in /opt/conda/lib/python3.10/site-packages (from pysal) (1.1.9)
# Requirement already satisfied: esda>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from pysal) (2.5.1)
# Requirement already satisfied: giddy>=2.3.3 in /opt/conda/lib/python3.10/site-packages (from pysal) (2.3.5)
# Requirement already satisfied: inequality>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pysal) (1.0.1)
# Requirement already satisfied: pointpats>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from pysal) (2.4.0)
# Requirement already satisfied: segregation>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from pysal) (2.5)
# Requirement already satisfied: spaghetti>=1.6.6 in /opt/conda/lib/python3.10/site-packages (from pysal) (1.7.5.post1)
# Requirement already satisfied: mgwr>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from pysal) (2.2.1)
# Requirement already satisfied: momepy>=0.5.3 in /opt/conda/lib/python3.10/site-packages (from pysal) (0.7.0)
# Requirement already satisfied: spglm>=1.0.8 in /opt/conda/lib/python3.10/site-packages (from pysal) (1.1.0)
# Requirement already satisfied: spint>=1.0.7 in /opt/conda/lib/python3.10/site-packages (from pysal) (1.0.7)
# Requirement already satisfied: spreg>=1.2.4 in /opt/conda/lib/python3.10/site-packages (from pysal) (1.4.2)
# Requirement already satisfied: spvcm>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from pysal) (0.3.0)
# Requirement already satisfied: tobler>=0.8.2 in /opt/conda/lib/python3.10/site-packages (from pysal) (0.11.2)
# Requirement already satisfied: mapclassify>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from pysal) (2.6.1)
# Requirement already satisfied: splot>=1.1.5.post1 in /opt/conda/lib/python3.10/site-packages (from pysal) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from pysal) (0.6.0)
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.10/site-packages (from access>=1.1.8->pysal) (0.14.3)
# Requirement already satisfied: numpy>=1.3 in /opt/conda/lib/python3.10/site-packages (from access>=1.1.8->pysal) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in /opt/conda/lib/python3.10/site-packages (from access>=1.1.8->pysal) (2.2.2)
# Requirement already satisfied: requests>=2 in /opt/conda/lib/python3.10/site-packages (from access>=1.1.8->pysal) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.10/site-packages (from esda>=2.4.1->pysal) (1.2.2)
# Requirement already satisfied: scipy>=1.9 in /opt/conda/lib/python3.10/site-packages (from esda>=2.4.1->pysal) (1.11.4)
# Requirement already satisfied: quantecon>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from giddy>=2.3.3->pysal) (0.7.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (4.12.2)
# Requirement already satisfied: packaging>=22 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (24.0)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (4.2.0)
# Requirement already satisfied: shapely>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.6.2->pysal) (2.0.4)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.10/site-packages (from mapclassify>=2.4.3->pysal) (3.2.1)
# Requirement already satisfied: tqdm>=4.63.0 in /opt/conda/lib/python3.10/site-packages (from momepy>=0.5.3->pysal) (4.66.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from pointpats>=2.2.0->pysal) (3.7.5)
# Requirement already satisfied: deprecation in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (2.1.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (1.4.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (0.12.2)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (0.58.1)
# Requirement already satisfied: pyproj>=3 in /opt/conda/lib/python3.10/site-packages (from segregation>=2.3.1->pysal) (3.6.1)
# Requirement already satisfied: rtree>=1.0 in /opt/conda/lib/python3.10/site-packages (from spaghetti>=1.6.6->pysal) (1.2.0)
# Requirement already satisfied: pulp>=2.7 in /opt/conda/lib/python3.10/site-packages (from spopt>=0.4.1->pysal) (2.8.0)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.10/site-packages (from tobler>=0.8.2->pysal) (1.3.10)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from tobler>=0.8.2->pysal) (0.14.1)
# Requirement already satisfied: rasterstats in /opt/conda/lib/python3.10/site-packages (from tobler>=0.8.2->pysal) (0.19.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.10->libpysal>=4.6.2->pysal) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas->access>=1.1.8->pysal) (1.9.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2023.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from pyproj>=3->segregation>=2.3.1->pysal) (2024.2.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.12)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->segregation>=2.3.1->pysal) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2->access>=1.1.8->pysal) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2->access>=1.1.8->pysal) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2->access>=1.1.8->pysal) (1.26.18)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0->esda>=2.4.1->pysal) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.2.0->pysal) (3.1.1)
# Requirement already satisfied: affine in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (23.2.0)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.8.2->pysal) (69.0.3)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.10/site-packages (from rasterstats->tobler>=0.8.2->pysal) (3.19.2)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels->tobler>=0.8.2->pysal) (0.5.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->access>=1.1.8->pysal) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/pysal/pysal.git
# Out:
# Collecting git+https://github.com/pysal/pysal.git
#   Cloning https://github.com/pysal/pysal.git to /tmp/pip-req-build-y4iw1vn2
#   Running command git clone --filter=blob:none --quiet https://github.com/pysal/pysal.git /tmp/pip-req-build-y4iw1vn2
#   Resolved https://github.com/pysal/pysal.git to commit c3b606cd7eaa92a191e8023c1187e1876eb4a10c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: libpysal>=4.9.2 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (4.9.2)
# Requirement already satisfied: access>=1.1.9 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (1.1.9)
# Requirement already satisfied: esda>=2.5.1 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (2.5.1)
# Requirement already satisfied: giddy>=2.3.5 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (2.3.5)
# Requirement already satisfied: inequality>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (1.0.1)
# Requirement already satisfied: pointpats>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (2.4.0)
# Requirement already satisfied: segregation>=2.5 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (2.5)
# Requirement already satisfied: spaghetti>=1.7.5.post1 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (1.7.5.post1)
# Requirement already satisfied: mgwr>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (2.2.1)
# Requirement already satisfied: momepy>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (0.7.0)
# Requirement already satisfied: spglm>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (1.1.0)
# Requirement already satisfied: spint>=1.0.7 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (1.0.7)
# Requirement already satisfied: spreg>=1.4.2 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (1.4.2)
# Requirement already satisfied: spvcm>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (0.3.0)
# Requirement already satisfied: tobler>=0.11.2 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (0.11.2)
# Requirement already satisfied: mapclassify>=2.6.1 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (2.6.1)
# Requirement already satisfied: splot>=1.1.5.post1 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pysal==24.1rc1+6.gc3b606cd) (0.6.0)
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.10/site-packages (from access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (0.14.3)
# Requirement already satisfied: numpy>=1.3 in /opt/conda/lib/python3.10/site-packages (from access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in /opt/conda/lib/python3.10/site-packages (from access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (2.2.2)
# Requirement already satisfied: requests>=2 in /opt/conda/lib/python3.10/site-packages (from access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.10/site-packages (from esda>=2.5.1->pysal==24.1rc1+6.gc3b606cd) (1.2.2)
# Requirement already satisfied: scipy>=1.9 in /opt/conda/lib/python3.10/site-packages (from esda>=2.5.1->pysal==24.1rc1+6.gc3b606cd) (1.11.4)
# Requirement already satisfied: quantecon>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from giddy>=2.3.5->pysal==24.1rc1+6.gc3b606cd) (0.7.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.9.2->pysal==24.1rc1+6.gc3b606cd) (4.12.2)
# Requirement already satisfied: packaging>=22 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.9.2->pysal==24.1rc1+6.gc3b606cd) (24.0)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.9.2->pysal==24.1rc1+6.gc3b606cd) (4.2.0)
# Requirement already satisfied: shapely>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.9.2->pysal==24.1rc1+6.gc3b606cd) (2.0.4)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.10/site-packages (from mapclassify>=2.6.1->pysal==24.1rc1+6.gc3b606cd) (3.2.1)
# Requirement already satisfied: tqdm>=4.63.0 in /opt/conda/lib/python3.10/site-packages (from momepy>=0.7.0->pysal==24.1rc1+6.gc3b606cd) (4.66.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from pointpats>=2.4.0->pysal==24.1rc1+6.gc3b606cd) (3.7.5)
# Requirement already satisfied: deprecation in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal==24.1rc1+6.gc3b606cd) (2.1.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal==24.1rc1+6.gc3b606cd) (1.4.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal==24.1rc1+6.gc3b606cd) (0.12.2)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal==24.1rc1+6.gc3b606cd) (0.58.1)
# Requirement already satisfied: pyproj>=3 in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal==24.1rc1+6.gc3b606cd) (3.6.1)
# Requirement already satisfied: rtree>=1.0 in /opt/conda/lib/python3.10/site-packages (from spaghetti>=1.7.5.post1->pysal==24.1rc1+6.gc3b606cd) (1.2.0)
# Requirement already satisfied: pulp>=2.7 in /opt/conda/lib/python3.10/site-packages (from spopt>=0.6.0->pysal==24.1rc1+6.gc3b606cd) (2.8.0)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.10/site-packages (from tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (1.3.10)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (0.14.1)
# Requirement already satisfied: rasterstats in /opt/conda/lib/python3.10/site-packages (from tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (0.19.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.10->libpysal>=4.9.2->pysal==24.1rc1+6.gc3b606cd) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (1.9.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (2023.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from pyproj>=3->segregation>=2.5->pysal==24.1rc1+6.gc3b606cd) (2024.2.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from quantecon>=0.4.7->giddy>=2.3.5->pysal==24.1rc1+6.gc3b606cd) (1.12)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->segregation>=2.5->pysal==24.1rc1+6.gc3b606cd) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (1.26.18)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0->esda>=2.5.1->pysal==24.1rc1+6.gc3b606cd) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal==24.1rc1+6.gc3b606cd) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal==24.1rc1+6.gc3b606cd) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal==24.1rc1+6.gc3b606cd) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal==24.1rc1+6.gc3b606cd) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal==24.1rc1+6.gc3b606cd) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal==24.1rc1+6.gc3b606cd) (3.1.1)
# Requirement already satisfied: affine in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (23.2.0)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (69.0.3)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.10/site-packages (from rasterstats->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (3.19.2)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels->tobler>=0.11.2->pysal==24.1rc1+6.gc3b606cd) (0.5.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->access>=1.1.9->pysal==24.1rc1+6.gc3b606cd) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.5->pysal==24.1rc1+6.gc3b606cd) (1.3.0)
# Building wheels for collected packages: pysal
#   Building wheel for pysal (setup.py) ... done
#   Created wheel for pysal: filename=pysal-24.1rc1+6.gc3b606cd-py3-none-any.whl size=18152 sha256=d6eff06d27d69cbca6863418899d70aaa8fa60b63b468d359e66c77895a60efc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ozex1f1d/wheels/98/70/e5/a56386a3f0a3406e027ffa30e4e7216d42dcfce0fd86f6d6eb
# Successfully built pysal
# Installing collected packages: pysal
#   Attempting uninstall: pysal
#     Found existing installation: pysal 24.1
#     Uninstalling pysal-24.1:
#       Successfully uninstalled pysal-24.1
# Successfully installed pysal-24.1rc1+6.gc3b606cd
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/pysal/gwr.git
# Out:
# Collecting git+https://github.com/pysal/gwr.git
#   Cloning https://github.com/pysal/gwr.git to /tmp/pip-req-build-x0lkyvmv
#   Running command git clone --filter=blob:none --quiet https://github.com/pysal/gwr.git /tmp/pip-req-build-x0lkyvmv
#   Resolved https://github.com/pysal/gwr.git to commit 7a1d52cb1f0dd364c4be5723a20cda983061c337
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from gwr==1.0.1) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from gwr==1.0.1) (1.11.4)
# Requirement already satisfied: libpysal in /opt/conda/lib/python3.10/site-packages (from gwr==1.0.1) (4.9.2)
# Requirement already satisfied: pysal in /opt/conda/lib/python3.10/site-packages (from gwr==1.0.1) (24.1rc1+6.gc3b606cd)
# Requirement already satisfied: spglm in /opt/conda/lib/python3.10/site-packages (from gwr==1.0.1) (1.1.0)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr==1.0.1) (4.12.2)
# Requirement already satisfied: geopandas>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr==1.0.1) (0.14.3)
# Requirement already satisfied: packaging>=22 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr==1.0.1) (24.0)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr==1.0.1) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr==1.0.1) (4.2.0)
# Requirement already satisfied: requests>=2.27 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr==1.0.1) (2.31.0)
# Requirement already satisfied: shapely>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from libpysal->gwr==1.0.1) (2.0.4)
# Requirement already satisfied: access>=1.1.9 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (1.1.9)
# Requirement already satisfied: esda>=2.5.1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (2.5.1)
# Requirement already satisfied: giddy>=2.3.5 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (2.3.5)
# Requirement already satisfied: inequality>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (1.0.1)
# Requirement already satisfied: pointpats>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (2.4.0)
# Requirement already satisfied: segregation>=2.5 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (2.5)
# Requirement already satisfied: spaghetti>=1.7.5.post1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (1.7.5.post1)
# Requirement already satisfied: mgwr>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (2.2.1)
# Requirement already satisfied: momepy>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (0.7.0)
# Requirement already satisfied: spint>=1.0.7 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (1.0.7)
# Requirement already satisfied: spreg>=1.4.2 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (1.4.2)
# Requirement already satisfied: spvcm>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (0.3.0)
# Requirement already satisfied: tobler>=0.11.2 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (0.11.2)
# Requirement already satisfied: mapclassify>=2.6.1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (2.6.1)
# Requirement already satisfied: splot>=1.1.5.post1 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pysal->gwr==1.0.1) (0.6.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.10->libpysal->gwr==1.0.1) (2.5)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.10/site-packages (from esda>=2.5.1->pysal->gwr==1.0.1) (1.2.2)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal->gwr==1.0.1) (1.9.6)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal->gwr==1.0.1) (3.6.1)
# Requirement already satisfied: quantecon>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from giddy>=2.3.5->pysal->gwr==1.0.1) (0.7.2)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.10/site-packages (from mapclassify>=2.6.1->pysal->gwr==1.0.1) (3.2.1)
# Requirement already satisfied: tqdm>=4.63.0 in /opt/conda/lib/python3.10/site-packages (from momepy>=0.7.0->pysal->gwr==1.0.1) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal->gwr==1.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal->gwr==1.0.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal->gwr==1.0.1) (2023.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from pointpats>=2.4.0->pysal->gwr==1.0.1) (3.7.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr==1.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr==1.0.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr==1.0.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal->gwr==1.0.1) (2024.2.2)
# Requirement already satisfied: deprecation in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal->gwr==1.0.1) (2.1.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal->gwr==1.0.1) (1.4.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal->gwr==1.0.1) (0.12.2)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from segregation>=2.5->pysal->gwr==1.0.1) (0.58.1)
# Requirement already satisfied: rtree>=1.0 in /opt/conda/lib/python3.10/site-packages (from spaghetti>=1.7.5.post1->pysal->gwr==1.0.1) (1.2.0)
# Requirement already satisfied: pulp>=2.7 in /opt/conda/lib/python3.10/site-packages (from spopt>=0.6.0->pysal->gwr==1.0.1) (2.8.0)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.10/site-packages (from tobler>=0.11.2->pysal->gwr==1.0.1) (1.3.10)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from tobler>=0.11.2->pysal->gwr==1.0.1) (0.14.1)
# Requirement already satisfied: rasterstats in /opt/conda/lib/python3.10/site-packages (from tobler>=0.11.2->pysal->gwr==1.0.1) (0.19.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr==1.0.1) (23.2.0)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr==1.0.1) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr==1.0.1) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr==1.0.1) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->gwr==1.0.1) (1.16.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from quantecon>=0.4.7->giddy>=2.3.5->pysal->gwr==1.0.1) (1.12)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->segregation>=2.5->pysal->gwr==1.0.1) (0.41.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0->esda>=2.5.1->pysal->gwr==1.0.1) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal->gwr==1.0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal->gwr==1.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal->gwr==1.0.1) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal->gwr==1.0.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal->gwr==1.0.1) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats>=2.4.0->pysal->gwr==1.0.1) (3.1.1)
# Requirement already satisfied: affine in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal->gwr==1.0.1) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal->gwr==1.0.1) (1.4.7)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from rasterio->tobler>=0.11.2->pysal->gwr==1.0.1) (69.0.3)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.10/site-packages (from rasterstats->tobler>=0.11.2->pysal->gwr==1.0.1) (3.19.2)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels->tobler>=0.11.2->pysal->gwr==1.0.1) (0.5.6)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.5->pysal->gwr==1.0.1) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mgwr
# Out:
# Requirement already satisfied: mgwr in /opt/conda/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: scipy>=0.11 in /opt/conda/lib/python3.10/site-packages (from mgwr) (1.11.4)
# Requirement already satisfied: numpy>=1.3 in /opt/conda/lib/python3.10/site-packages (from mgwr) (1.26.4)
# Requirement already satisfied: libpysal>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mgwr) (4.9.2)
# Requirement already satisfied: spglm>=1.0.6 in /opt/conda/lib/python3.10/site-packages (from mgwr) (1.1.0)
# Requirement already satisfied: spreg in /opt/conda/lib/python3.10/site-packages (from mgwr) (1.4.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr) (4.12.2)
# Requirement already satisfied: geopandas>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr) (0.14.3)
# Requirement already satisfied: packaging>=22 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr) (24.0)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr) (4.2.0)
# Requirement already satisfied: requests>=2.27 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr) (2.31.0)
# Requirement already satisfied: shapely>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr) (2.0.4)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from spreg->mgwr) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.10->libpysal>=4.0.0->mgwr) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal>=4.0.0->mgwr) (1.9.6)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal>=4.0.0->mgwr) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal>=4.0.0->mgwr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal>=4.0.0->mgwr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal>=4.0.0->mgwr) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->spreg->mgwr) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->spreg->mgwr) (3.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr) (23.2.0)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://github.com/pysal/mgwr/archive/master.zip
# Out:
# Collecting https://github.com/pysal/mgwr/archive/master.zip
#   Downloading https://github.com/pysal/mgwr/archive/master.zip
#      | 7.1 MB 13.1 MB/s 0:00:00m
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=0.11 in /opt/conda/lib/python3.10/site-packages (from mgwr==2.2.1) (1.11.4)
# Requirement already satisfied: numpy>=1.3 in /opt/conda/lib/python3.10/site-packages (from mgwr==2.2.1) (1.26.4)
# Requirement already satisfied: libpysal>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mgwr==2.2.1) (4.9.2)
# Requirement already satisfied: spglm>=1.0.6 in /opt/conda/lib/python3.10/site-packages (from mgwr==2.2.1) (1.1.0)
# Requirement already satisfied: spreg in /opt/conda/lib/python3.10/site-packages (from mgwr==2.2.1) (1.4.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.2.1) (4.12.2)
# Requirement already satisfied: geopandas>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.2.1) (0.14.3)
# Requirement already satisfied: packaging>=22 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.2.1) (24.0)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.2.1) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.2.1) (4.2.0)
# Requirement already satisfied: requests>=2.27 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.2.1) (2.31.0)
# Requirement already satisfied: shapely>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->mgwr==2.2.1) (2.0.4)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from spreg->mgwr==2.2.1) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.10->libpysal>=4.0.0->mgwr==2.2.1) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal>=4.0.0->mgwr==2.2.1) (1.9.6)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal>=4.0.0->mgwr==2.2.1) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal>=4.0.0->mgwr==2.2.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal>=4.0.0->mgwr==2.2.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal>=4.0.0->mgwr==2.2.1) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr==2.2.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr==2.2.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr==2.2.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal>=4.0.0->mgwr==2.2.1) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->spreg->mgwr==2.2.1) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->spreg->mgwr==2.2.1) (3.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr==2.2.1) (23.2.0)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr==2.2.1) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr==2.2.1) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr==2.2.1) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal>=4.0.0->mgwr==2.2.1) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install libpysal
# Out:
# Requirement already satisfied: libpysal in /opt/conda/lib/python3.10/site-packages (4.9.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/conda/lib/python3.10/site-packages (from libpysal) (4.12.2)
# Requirement already satisfied: geopandas>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from libpysal) (0.14.3)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.10/site-packages (from libpysal) (1.26.4)
# Requirement already satisfied: packaging>=22 in /opt/conda/lib/python3.10/site-packages (from libpysal) (24.0)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.10/site-packages (from libpysal) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from libpysal) (4.2.0)
# Requirement already satisfied: requests>=2.27 in /opt/conda/lib/python3.10/site-packages (from libpysal) (2.31.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from libpysal) (1.11.4)
# Requirement already satisfied: shapely>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from libpysal) (2.0.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.10->libpysal) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal) (1.9.6)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from geopandas>=0.10.0->libpysal) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4->libpysal) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27->libpysal) (2024.2.2)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (23.2.0)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown
# Đường dẫn chia sẻ của file trên Google Drive
#2019 
google_drive_url_test = "https://drive.google.com/uc?id=1UdF7pDcDeJeqGpbnKo2CoG9yRFL9sXv3"

# Đường dẫn đến nơi lưu trữ file trên Kaggle
output_path_test = "/kaggle/working/data_test.csv"

# Tải file từ Google Drive
gdown.download(google_drive_url_test, output_path_test, quiet=False)

#2020 
google_drive_url_training = "https://drive.google.com/uc?id=1jBwALQEtJpGMaRIkCxyPXdoK2NETwNl8"

# Đường dẫn đến nơi lưu trữ file trên Kaggle
output_path_training = "/kaggle/working/data_train.csv"

# Tải file từ Google Drive
gdown.download(google_drive_url_training, output_path_training, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UdF7pDcDeJeqGpbnKo2CoG9yRFL9sXv3
# To: /kaggle/working/data_test.csv
# 100%|██████████| 3.28M/3.28M [00:00<00:00, 154MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jBwALQEtJpGMaRIkCxyPXdoK2NETwNl8
# To: /kaggle/working/data_train.csv
# 100%|██████████| 8.36M/8.36M [00:00<00:00, 97.5MB/s]
# '/kaggle/working/data_train.csv'

# %% [markdown]
# Dataframe for training gwr

# %%
import pandas as pd

# Đọc tệp CSV và tạo DataFrame
df_train = pd.read_csv(output_path_training)

# Hiển thị df_validate
print(df_train)
# Out:
#        AWS  Row Position  Column Position            name    DEM  Imerg  \
# 0      0.4            73              128  20200401000000     42    0.0
# 1      0.0            80               82  20200401000000    158    0.0
# 2      0.0            79              229  20200401000000  32767    0.0
# 3      0.0            75              158  20200401000000  32767    0.0
# 4      0.0            69               79  20200401000000    562    0.0
# ...    ...           ...              ...             ...    ...    ...
# 99995  0.0            61              100  20201031230000    950    0.0
# 99996  0.0            58              158  20201031230000  32767    0.0
# 99997  0.0            54              128  20201031230000      0    0.0
# 99998  0.0            37              138  20201031230000      0    0.0
# 99999  0.0            29               25  20201031230000    587    0.0
#
#             R500      SLHF      TCLW       TCWV
# 0      26.537556 -190534.0  0.295776  44.956818
# 1      13.021932  -89222.0  0.003479  36.245880
# 2      13.350057 -158470.0  0.017700  35.447052
# 3      20.342243  -26502.0  0.059570  46.316193
# 4      13.920369  -72006.0  0.002258  31.788849
# ...          ...       ...       ...        ...
# 99995  45.053467  -12279.0  0.213165  39.263230
# 99996  55.401123 -428727.0  0.004456  50.606980
# 99997  58.467530 -329847.0  0.078552  51.524950
# 99998  70.264404 -226679.0  0.108276  50.776900
# 99999  44.580810     713.0  0.129730  46.105026
#
# [100000 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo ma trận tương quan
corr_matrix = df_train[['AWS', 'Imerg', 'DEM', 'R500', 'SLHF', 'TCLW', 'TCWV']].corr()

# Vẽ heatmap của ma trận tương quan
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Ma trận tương quan giữa các biến độc lập')
plt.show()

# %% [markdown]
# Dataframe for test GWR

# %%
import pandas as pd

# Đọc tệp CSV và tạo df_test
df_test = pd.read_csv(output_path_test)

# Hiển thị df_test
print(df_test)
# Out:
#        AWS  Row Position  Column Position            name  DEM     Imerg  \
# 0      0.8            16              109  20190401000000  350  0.000000
# 1      0.0            83               69  20190401000000  162  0.000000
# 2      0.0            82               18  20190401000000  260  0.000000
# 3      0.0             7              173  20190401000000    0  0.000000
# 4      0.0            77              235  20190401000000    0  0.000000
# ...    ...           ...              ...             ...  ...       ...
# 39995  0.2            20              103  20191031230000  357  0.000000
# 39996  1.9            20              135  20191031230000    9  3.327910
# 39997  0.2            21              129  20191031230000    9  2.202812
# 39998  1.6            67              121  20191031230000  258  3.217461
# 39999  0.0            82               59  20191031230000  164  0.208975
#
#             R500      SLHF      TCLW       TCWV
# 0      29.947826  -57959.0  0.776672  45.834610
# 1      28.303295  -63719.0  0.049072  39.783830
# 2       6.088452  -40615.0  0.088745  39.867813
# 3      18.381420 -495207.0  0.104919  42.965470
# 4      19.690014 -183527.0  0.065857  47.904922
# ...          ...       ...       ...        ...
# 39995  52.955520  -70022.0  0.494751  48.253937
# 39996  95.748490 -650246.0  0.363342  58.279327
# 39997  90.225050 -335622.0  0.337280  56.781280
# 39998  97.162550 -451590.0  0.913269  60.759796
# 39999  77.381300 -163590.0  0.087463  49.972687
#
# [40000 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_test = df_test.rename(columns={'aws': 'AWS'})

# Tạo ma trận tương quan
corr_matrix = df_test[['AWS', 'Imerg', 'DEM', 'R500', 'SLHF', 'TCLW', 'TCWV']].corr()

# Vẽ heatmap của ma trận tương quan
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Ma trận tương quan giữa các biến độc lập')
plt.show()

# %% [markdown]
# Build GWR model

# %%
import numpy as np
import pandas as pd
import libpysal as ps
from mgwr.gwr import GWR, MGWR
from mgwr.sel_bw import Sel_BW
from mgwr.utils import compare_surfaces, truncate_colormap
import geopandas as gp
import matplotlib.pyplot as plt
import matplotlib as mpl
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

# %%
# Chuẩn bị dữ liệu đầu vào
y = df_train['AWS'].values.reshape((-1, 1))
X = df_train[['Imerg', 'R500', 'SLHF', 'TCLW', 'TCWV']].values

# Các tọa độ không gian
coords = df_train[['Row Position', 'Column Position']].values

# Lựa chọn bandwidth tối ưu
gwr_selector = Sel_BW(coords, y, X)
gwr_bw = gwr_selector.search()
print(gwr_bw)

# Calibrate mô hình GWR
model = GWR(coords, y, X, gwr_bw)
gwr_results = model.fit()
# Out:
# 377.0

# %%
# Chuẩn bị dữ liệu không gian và vẽ các hệ số
gdf = gp.GeoDataFrame(df_train, geometry=gp.points_from_xy(df_train['Column Position'], df_train['Row Position']))
gdf['Intercept'] = gwr_results.params[:, 0]
gdf['Imerg_coef'] = gwr_results.params[:, 1]
gdf['R500_coef'] = gwr_results.params[:, 2]
gdf['SLHF_coef'] = gwr_results.params[:, 3]
gdf['TCLW_coef'] = gwr_results.params[:, 4]
gdf['TCWV_coef'] = gwr_results.params[:, 5]

fig, axes = plt.subplots(3, 2, figsize=(15, 20))
columns = ['Intercept', 'Imerg_coef', 'R500_coef', 'SLHF_coef', 'TCLW_coef', 'TCWV_coef']  
for ax, column in zip(axes.flatten(), columns):
    gdf.plot(column=column, cmap='coolwarm', ax=ax, legend=True)
    ax.set_title(f'{column} spatial distribution')

plt.tight_layout()
plt.show()

# %%
import pickle

# Lưu model và trọng số vào file
with open('/kaggle/working/gwr_model.pkl', 'wb') as f:
    pickle.dump(model, f)
    pickle.dump(gwr_results, f)

# %%
# Kiểm tra và chuẩn bị dữ liệu test cho df_test_1
y_test = df_test['AWS'].values.reshape((-1, 1))
X_test = df_test[['Imerg', 'R500', 'SLHF', 'TCLW', 'TCWV']]  
coords_test = df_test[['Row Position', 'Column Position']].values

# Dự đoán giá trị cho tập test
scale = gwr_results.scale
residuals = gwr_results.resid_response
pred_y = model.predict(coords_test, X_test, scale, residuals)

# Hiển thị kết quả
plt.scatter(y_test, pred_y.predictions)
plt.xlabel('Actual AWS')
plt.ylabel('Predicted AWS')
plt.title('Actual vs. Predicted AWS for df_test')
plt.show()

# %%
print(y_test.shape)
print(pred_y.predictions.shape)
# Out:
# (40000, 1)
# (40000, 1)

# %%
# Lưu kết quả dự đoán vào tệp CSV
results_df = pd.DataFrame({
    'Actual AWS': y_test.flatten(),
    'Predicted AWS': pred_y.predictions.flatten()
})
results_df.to_csv('predictions_GWR.csv', index=False)
